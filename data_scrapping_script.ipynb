# %% [markdown]
# # Scrap data from Cars 24

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium import webdriver
from selenium.webdriver.common.by import By

# %% [markdown]
# ### New Delhi Loaction

# %%
driver = webdriver.Chrome(r"D:\chromedriver.exe")  # Optional argument, if not specified will search path.
driver.get('https://www.cars24.com/');

time.sleep(5)

# %%
wait = WebDriverWait(driver, 10)
element = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')))
element.click()

# %%
element1 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button')))
element1.click()

# %%
element2 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[1]/a/span/img')))
element2.click()

# %%
element3 = wait.until(EC.element_to_be_clickable((By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div[2]/button')))
element3.click()

# %% [markdown]
# ### Infinite Scrolling

# %%
SCROLL_PAUSE_TIME = 20

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

container=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_1l4fi']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container.append(p)

# %%
len(container)
# Out:
# 573

# %%
Make_year=[]
Brand=[]
Model=[]
Transmission=[]
Kms=[]
Owner=[]
variant=[]
Price=[]
City=[]

# %%
container1=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container1.append(p)

# %%
for i in range(0,len(container1)):
    Price.append(container1[i])

# %%
container2=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container2.append(p)

# %%
for i in range(0,len(container2)):
    if 'Hybrid' in container[i][1]:
        variant.append('Petrol + Ev')
    elif 'HYBRID' in container[i][1]:
        variant.append('Petrol + Ev')
    else:
        variant.append(container2[i][2])

# %%
for i in range(0,len(container)):
    a=container[i][0]
    Make_year.append(a[0:4])
    Brand.append(a[5::])
    Model.append(container[i][1])
    Kms.append(container[i][2])
    Owner.append(container[i][3])
    City.append('New Delhi')
    if 'Automatic' in container[i][1]:
        Transmission.append('Automatic')
    elif 'AUTOMATIC' in container[i][1]:
        Transmission.append('Automatic')
    else:
        Transmission.append('Manual')

# %%
data=list(zip(Make_year,Brand,Model,Transmission,Kms,Owner,variant,City,Price))
              
df= pd.DataFrame(data, columns=['Make_Year','Brand','Model','Transmission','Kms','Owner','Variant','City','Price'])

df
# Out:
#     Make_Year                  Brand                         Model  \
# 0        2019          Hyundai Verna        1.6 SX VTVT (O) Manual
# 1        2014  Mercedes Benz C Class    C 200 AVANTGARDE Automatic
# 2        2020             KIA SELTOS     GTX + AT PETROL Automatic
# 3        2013      Hyundai Grand i10  SPORTZ 1.2 KAPPA VTVT Manual
# 4        2020             KIA SELTOS      HTX 1.5 PETROL MT Manual
# ..        ...                    ...                           ...
# 568      2018           Maruti Swift                    LXI Manual
# 569      2018           Maruti Swift                    VDI Manual
# 570      2012           Maruti Swift                    ZXI Manual
# 571      2018     Maruti Wagon R 1.0                    LXI Manual
# 572      2014         Maruti Celerio             VXI AMT Automatic
#
#     Transmission        Kms      Owner Variant       City         Price
# 0         Manual  81,902 km  1st Owner  Petrol  New Delhi   [₹9,81,699]
# ...

# %%
driver.quit()

# %% [markdown]
# ### Location Mumbai

# %%
driver = webdriver.Chrome(r"D:\chromedriver.exe")  # Optional argument, if not specified will search path.
driver.get('https://www.cars24.com/');

time.sleep(5)

# %%
wait = WebDriverWait(driver, 10)
element = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')))
element.click()

# %%
element2 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button')))
element2.click()

# %%
element3 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[4]/a/span/img')))
element3.click()

# %%
element4 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[2]/div[2]/button')))
element4.click()

# %%
SCROLL_PAUSE_TIME = 20

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
container=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_1l4fi']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container.append(p)
    
Make_year=[]
Brand=[]
Model=[]
Transmission=[]
Kms=[]
Owner=[]
variant=[]
Price=[]
City=[]

container1=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container1.append(p)
    
for i in range(0,len(container1)):
    Price.append(container1[i])

# %%
container2=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container2.append(p)
    
for i in range(0,len(container2)):
    if 'Hybrid' in container[i][1]:
        variant.append('Petrol + Ev')
    elif 'HYBRID' in container[i][1]:
        variant.append('Petrol + Ev')
    else:
        variant.append(container2[i][2])
    
for i in range(0,len(container)):
    a=container[i][0]
    Make_year.append(a[0:4])
    Brand.append(a[5::])
    Model.append(container[i][1])
    Kms.append(container[i][2])
    Owner.append(container[i][3])
    City.append('Mumbai')
    if 'Automatic' in container[i][1]:
        Transmission.append('Automatic')
    elif 'AUTOMATIC' in container[i][1]:
        Transmission.append('Automatic')
    else:
        Transmission.append('Manual')
        
data=list(zip(Make_year,Brand,Model,Transmission,Kms,Owner,variant,City,Price))
              
df1= pd.DataFrame(data, columns=['Make_Year','Brand','Model','Transmission','Kms','Owner','Variant','City','Price'])

df1
# Out:
#     Make_Year                 Brand                           Model  \
# 0        2011  Toyota Corolla Altis                    1.8 G Manual
# 1        2013           Maruti Ritz                      ZXI Manual
# 2        2016         Maruti Baleno            DELTA 1.2 K12 Manual
# 3        2012          Honda Accord                   2.4 MT Manual
# 4        2016       Volkswagen Polo    TRENDLINE 1.2L PETROL Manual
# ..        ...                   ...                             ...
# 509      2018    Maruti Wagon R 1.0                  LXI CNG Manual
# 510      2019    Maruti New Wagon-R      1.2L VXI (O) AGS Automatic
# 511      2016     Hyundai Grand i10  ASTA 1.2 KAPPA VTVT OPT Manual
# 512      2016         Hyundai Creta       1.6 SX PLUS PETROL Manual
# 513      2016  Maruti Vitara Brezza                      VDI Manual
#
#     Transmission          Kms      Owner       Variant    City        Price
# ...

# %%
driver.quit()

# %% [markdown]
# ### Gurugram(Gurgaon) Location

# %%
driver = webdriver.Chrome(r"D:\chromedriver.exe")  # Optional argument, if not specified will search path.
driver.get('https://www.cars24.com/');

time.sleep(5)

wait = WebDriverWait(driver, 10)
element = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')))
element.click()

element2 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button')))
element2.click()

# %%
element3 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[3]/a/span/img')))
element3.click()

element4 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[2]/div[2]/button')))
element4.click()

# %%
SCROLL_PAUSE_TIME = 20

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
container=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_1l4fi']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container.append(p)
    
Make_year=[]
Brand=[]
Model=[]
Transmission=[]
Kms=[]
Owner=[]
variant=[]
Price=[]
City=[]

container1=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container1.append(p)
    
for i in range(0,len(container1)):
    Price.append(container1[i])
    
container2=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container2.append(p)
    
for i in range(0,len(container2)):
    if 'Hybrid' in container[i][1]:
        variant.append('Petrol + Ev')
    elif 'HYBRID' in container[i][1]:
        variant.append('Petrol + Ev')
    else:
        variant.append(container2[i][2])
    
for i in range(0,len(container)):
    a=container[i][0]
    Make_year.append(a[0:4])
    Brand.append(a[5::])
    Model.append(container[i][1])
    Kms.append(container[i][2])
    Owner.append(container[i][3])
    City.append("Gurgaon")
    if 'Automatic' in container[i][1]:
        Transmission.append('Automatic')
    elif 'AUTOMATIC' in container[i][1]:
        Transmission.append('Automatic')
    else:
        Transmission.append('Manual')
        
data=list(zip(Make_year,Brand,Model,Transmission,Kms,Owner,variant,City,Price))
              
df2= pd.DataFrame(data, columns=['Make_Year','Brand','Model','Transmission','Kms','Owner','Variant','City','Price'])

df2
# Out:
#     Make_Year               Brand                           Model  \
# 0        2019        Jeep Compass         1.4 SPORT PETROL Manual
# 1        2019        Jeep Compass  1.4 LONGITUDE (O) AT Automatic
# 2        2019        Jeep Compass              2.0 LIMITED Manual
# 3        2010          Honda City              S MT PETROL Manual
# 4        2019           MG HECTOR      SHARP DCT PETROL Automatic
# ..        ...                 ...                             ...
# 588      2018        Maruti Swift                      LXI Manual
# 589      2018        Maruti Swift                      VDI Manual
# 590      2012        Maruti Swift                      ZXI Manual
# 591      2018  Maruti Wagon R 1.0                      LXI Manual
# 592      2014      Maruti Celerio               VXI AMT Automatic
#
#     Transmission        Kms      Owner Variant     City         Price
# 0         Manual  42,490 km  2nd Owner  Petrol  Gurgaon  [₹13,89,799]
# ...

# %%
driver.quit()

# %% [markdown]
# ### Kolkata Location

# %%
driver = webdriver.Chrome(r"D:\chromedriver.exe")  # Optional argument, if not specified will search path.
driver.get('https://www.cars24.com/');

time.sleep(5)

wait = WebDriverWait(driver, 10)
element = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')))
element.click()

element2 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button')))
element2.click()

# %%
element3 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[9]/a/span/img')))
element3.click()

element4 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[2]/div[2]/button')))
element4.click()

# %%
SCROLL_PAUSE_TIME = 20

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
container=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_1l4fi']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container.append(p)
    
Make_year=[]
Brand=[]
Model=[]
Transmission=[]
Kms=[]
Owner=[]
variant=[]
Price=[]
City=[]

container1=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container1.append(p)
    
for i in range(0,len(container1)):
    Price.append(container1[i])
    
container2=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container2.append(p)
    
for i in range(0,len(container2)):
    if 'Hybrid' in container[i][1]:
        variant.append('Petrol + Ev')
    elif 'HYBRID' in container[i][1]:
        variant.append('Petrol + Ev')
    else:
        variant.append(container2[i][2])
    
for i in range(0,len(container)):
    a=container[i][0]
    Make_year.append(a[0:4])
    Brand.append(a[5::])
    Model.append(container[i][1])
    Kms.append(container[i][2])
    Owner.append(container[i][3])
    City.append("Kolkata")
    if 'Automatic' in container[i][1]:
        Transmission.append('Automatic')
    elif 'AUTOMATIC' in container[i][1]:
        Transmission.append('Automatic')
    else:
        Transmission.append('Manual')
        
data=list(zip(Make_year,Brand,Model,Transmission,Kms,Owner,variant,City,Price))
              
df3= pd.DataFrame(data, columns=['Make_Year','Brand','Model','Transmission','Kms','Owner','Variant','City','Price'])

df3
# Out:
#     Make_Year             Brand                   Model Transmission  \
# 0        2021     Hyundai VENUE   S MT 1.2 KAPPA Manual       Manual
# 1        2018      Maruti Swift              VXI Manual       Manual
# 2        2021     Hyundai VENUE   S MT 1.2 KAPPA Manual       Manual
# 3        2020     Ford Ecosport   1.5 TREND TDCI Manual       Manual
# 4        2016   Maruti Alto K10              VXI Manual       Manual
# ..        ...               ...                     ...          ...
# 231      2020      Renault Kwid          RXT Opt Manual       Manual
# 232      2015  Mahindra Scorpio              S10 Manual       Manual
# 233      2015   Maruti Alto 800              LXI Manual       Manual
# 234      2020     Maruti Baleno    DELTA 1.2 K12 Manual       Manual
# 235      2013       Hyundai i10  MAGNA 1.1 IRDE2 Manual       Manual
#
#            Kms      Owner Variant     City        Price
# 0     7,239 km  1st Owner  Petrol  Kolkata  [₹8,02,699]
# ...

# %%
driver.quit()

# %% [markdown]
# ### Noida Location

# %%
driver = webdriver.Chrome(r"D:\chromedriver.exe")  # Optional argument, if not specified will search path.
driver.get('https://www.cars24.com/');

time.sleep(5)

wait = WebDriverWait(driver, 10)
element = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')))
element.click()

element2 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button')))
element2.click()

# %%
element3 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[2]/a/span/img')))
element3.click()

element4 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[2]/div[2]/button')))
element4.click()

# %%
SCROLL_PAUSE_TIME = 20

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
container=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_1l4fi']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container.append(p)
    
Make_year=[]
Brand=[]
Model=[]
Transmission=[]
Kms=[]
Owner=[]
variant=[]
Price=[]
City=[]

container1=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container1.append(p)
    
for i in range(0,len(container1)):
    Price.append(container1[i])
    
container2=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container2.append(p)
    
for i in range(0,len(container2)):
    if 'Hybrid' in container[i][1]:
        variant.append('Petrol + Ev')
    elif 'HYBRID' in container[i][1]:
        variant.append('Petrol + Ev')
    else:
        variant.append(container2[i][2])
    
for i in range(0,len(container)):
    a=container[i][0]
    Make_year.append(a[0:4])
    Brand.append(a[5::])
    Model.append(container[i][1])
    Kms.append(container[i][2])
    Owner.append(container[i][3])
    City.append("Noida")
    if 'Automatic' in container[i][1]:
        Transmission.append('Automatic')
    elif 'AUTOMATIC' in container[i][1]:
        Transmission.append('Automatic')
    else:
        Transmission.append('Manual')
        
data=list(zip(Make_year,Brand,Model,Transmission,Kms,Owner,variant,City,Price))
              
df4= pd.DataFrame(data, columns=['Make_Year','Brand','Model','Transmission','Kms','Owner','Variant','City','Price'])

df4
# Out:
#     Make_Year               Brand                  Model Transmission  \
# 0        2020   Hyundai Grand i10  MAGNA 1.2 VTVT Manual       Manual
# 1        2020   Hyundai Grand i10  MAGNA 1.2 VTVT Manual       Manual
# 2        2009         Hyundai i10    ERA 1.1 IRDE Manual       Manual
# 3        2020        Maruti IGNIS   SIGMA 1.2 K12 Manual       Manual
# 4        2014        Nissan Micra       XE DIESEL Manual       Manual
# ..        ...                 ...                    ...          ...
# 588      2018        Maruti Swift             LXI Manual       Manual
# 589      2018        Maruti Swift             VDI Manual       Manual
# 590      2012        Maruti Swift             ZXI Manual       Manual
# 591      2018  Maruti Wagon R 1.0             LXI Manual       Manual
# 592      2014      Maruti Celerio      VXI AMT Automatic    Automatic
#
#            Kms      Owner Variant   City        Price
# 0     6,470 km  1st Owner  Petrol  Noida  [₹6,08,399]
# ...

# %%
driver.quit()

# %% [markdown]
# ### Chennai Location

# %%
driver = webdriver.Chrome(r"D:\chromedriver.exe")  # Optional argument, if not specified will search path.
driver.get('https://www.cars24.com/');

time.sleep(5)

wait = WebDriverWait(driver, 10)
element = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')))
element.click()

element2 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button')))
element2.click()

# %%
element3 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[8]/a/span/img')))
element3.click()

element4 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[2]/div[2]/button')))
element4.click()

# %%
SCROLL_PAUSE_TIME = 20

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
container=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_1l4fi']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container.append(p)
    
Make_year=[]
Brand=[]
Model=[]
Transmission=[]
Kms=[]
Owner=[]
variant=[]
Price=[]
City=[]

container1=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container1.append(p)
    
for i in range(0,len(container1)):
    Price.append(container1[i])
    
container2=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container2.append(p)
    
for i in range(0,len(container2)):
    if 'Hybrid' in container[i][1]:
        variant.append('Petrol + Ev')
    elif 'HYBRID' in container[i][1]:
        variant.append('Petrol + Ev')
    else:
        variant.append(container2[i][2])
    
for i in range(0,len(container)):
    a=container[i][0]
    Make_year.append(a[0:4])
    Brand.append(a[5::])
    Model.append(container[i][1])
    Kms.append(container[i][2])
    Owner.append(container[i][3])
    City.append("Chennai")
    if 'Automatic' in container[i][1]:
        Transmission.append('Automatic')
    elif 'AUTOMATIC' in container[i][1]:
        Transmission.append('Automatic')
    else:
        Transmission.append('Manual')
        
data=list(zip(Make_year,Brand,Model,Transmission,Kms,Owner,variant,City,Price))
              
df5= pd.DataFrame(data, columns=['Make_Year','Brand','Model','Transmission','Kms','Owner','Variant','City','Price'])

df5
# Out:
#     Make_Year                Brand                       Model Transmission  \
# 0        2012  Hyundai Santro Xing              GL PLUS Manual       Manual
# 1        2015         Maruti Swift                  VXI Manual       Manual
# 2        2017         Maruti Swift              VXI OPT Manual       Manual
# 3        2015         Maruti Swift                  VXI Manual       Manual
# 4        2013   Maruti Wagon R 1.0                  VXI Manual       Manual
# ..        ...                  ...                         ...          ...
# 513      2018          Hyundai Eon             ERA PLUS Manual       Manual
# 514      2016          Hyundai Eon             ERA PLUS Manual       Manual
# 515      2016          Hyundai i10      MAGNA 1.1 IRDE2 Manual       Manual
# 516      2017     Fiat URBAN CROSS        EMOTION MULTIJET 1.3       Manual
# 517      2016        Ford Ecosport  1.5 TITANIUM TI VCT Manual       Manual
#
#            Kms      Owner Variant     City        Price
# ...

# %%
driver.quit()

# %% [markdown]
# ## Pune Location

# %%
driver = webdriver.Chrome(r"D:\chromedriver.exe")  # Optional argument, if not specified will search path.
driver.get('https://www.cars24.com/');

time.sleep(5)

wait = WebDriverWait(driver, 10)
element = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')))
element.click()

element2 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button')))
element2.click()

# %%
element3 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[5]/a/span/img')))
element3.click()

element4 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[2]/div[2]/button')))
element4.click()

# %%
SCROLL_PAUSE_TIME = 20

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

container=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_1l4fi']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container.append(p)

# %%
Make_year=[]
Brand=[]
Model=[]
Transmission=[]
Kms=[]
Owner=[]
variant=[]
City=[]
Price=[]

# %%
container1=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container1.append(p)
    
for i in range(0,len(container1)):
    Price.append(container1[i])
    
container2=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container2.append(p)
    
for i in range(0,len(container2)):
    if 'Hybrid' in container[i][1]:
        variant.append('Petrol + Ev')
    elif 'HYBRID' in container[i][1]:
        variant.append('Petrol + Ev')
    else:
        variant.append(container2[i][2])
    
for i in range(0,len(container)):
    a=container[i][0]
    Make_year.append(a[0:4])
    Brand.append(a[5::])
    Model.append(container[i][1])
    Kms.append(container[i][2])
    Owner.append(container[i][3])
    City.append("Pune")
    if 'Automatic' in container[i][1]:
        Transmission.append('Automatic')
    elif 'AUTOMATIC' in container[i][1]:
        Transmission.append('Automatic')
    else:
        Transmission.append('Manual')
        
data=list(zip(Make_year,Brand,Model,Transmission,Kms,Owner,variant,City,Price))
              
df6= pd.DataFrame(data, columns=['Make_Year','Brand','Model','Transmission','Kms','Owner','Variant','City','Price'])

df6
# Out:
#     Make_Year                 Brand                           Model  \
# 0        2019           Skoda Rapid        1.6 MPI MT ACTIVE Manual
# 1        2012            Honda City                  V AT Automatic
# 2        2015  Toyota Corolla Altis             1.8G LIMITED Manual
# 3        2021        Nissan MAGNITE                    XL Turbo CVT
# 4        2014     Toyota Etios Liva                       GD Manual
# ..        ...                   ...                             ...
# 416      2018    Maruti Wagon R 1.0                  LXI CNG Manual
# 417      2016        Maruti S Cross                DELTA 1.6 Manual
# 418      2016            Honda Jazz                 1.2 V MT Manual
# 419      2016       Volkswagen Polo  COMFORTLINE 1.2L PETROL Manual
# 420      2015           Skoda Rapid  ELEGANCE 1.6 MPFI AT Automatic
#
#     Transmission        Kms      Owner       Variant  City        Price
# 0         Manual  10,435 km  1st Owner        Petrol  Pune  [₹8,00,799]
# ...

# %%
driver.quit()

# %% [markdown]
# ### Hyderabad

# %%
driver = webdriver.Chrome(r"D:\chromedriver.exe")  # Optional argument, if not specified will search path.
driver.get('https://www.cars24.com/');

time.sleep(5)

wait = WebDriverWait(driver, 10)
element = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')))
element.click()

element2 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button')))
element2.click()

# %%
element3 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[7]/a/span/img')))
element3.click()

element4 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[2]/div[2]/button')))
element4.click()

# %%
SCROLL_PAUSE_TIME = 20

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

container=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_1l4fi']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container.append(p)

# %%
Make_year=[]
Brand=[]
Model=[]
Transmission=[]
Kms=[]
Owner=[]
variant=[]
Price=[]
City=[]

# %%
container1=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container1.append(p)
    
for i in range(0,len(container1)):
    Price.append(container1[i])

# %%
container2=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container2.append(p)

# %%
for i in range(0,len(container2)):
    if 'Hybrid' in container[i][1]:
        variant.append('Petrol + Ev')
    elif 'HYBRID' in container[i][1]:
        variant.append('Petrol + Ev')
    else:
        variant.append(container2[i][2])
    
for i in range(0,len(container)):
    a=container[i][0]
    Make_year.append(a[0:4])
    Brand.append(a[5::])
    Model.append(container[i][1])
    Kms.append(container[i][2])
    Owner.append(container[i][3])
    City.append("Hyderabad")
    if 'Automatic' in container[i][1]:
        Transmission.append('Automatic')
    elif 'AUTOMATIC' in container[i][1]:
        Transmission.append('Automatic')
    else:
        Transmission.append('Manual')
        
data=list(zip(Make_year,Brand,Model,Transmission,Kms,Owner,variant,City,Price))
              
df7= pd.DataFrame(data, columns=['Make_Year','Brand','Model','Transmission','Kms','Owner','Variant','City','Price'])

df7
# Out:
#     Make_Year               Brand                     Model Transmission  \
# 0        2010         Hyundai i10          MAGNA 1.2 Manual       Manual
# 1        2010         Hyundai i10         SPORTZ 1.2 Manual       Manual
# 2        2010         Hyundai i10          MAGNA 1.2 Manual       Manual
# 3        2013     Maruti Alto 800                LXI Manual       Manual
# 4        2010          Honda City        S MT PETROL Manual       Manual
# ..        ...                 ...                       ...          ...
# 397      2019  Hyundai NEW SANTRO  1.1 SPORTS AMT Automatic    Automatic
# 398      2016       Maruti Baleno      ALPHA 1.2 K12 Manual       Manual
# 399      2020       Maruti Baleno       ZETA 1.2 K12 Manual       Manual
# 400      2020        Renault Kwid                RXL Manual       Manual
# 401      2017  Hyundai i20 Active              1.2 S Manual       Manual
#
#            Kms      Owner Variant       City        Price
# ...

# %%
driver.quit()

# %% [markdown]
# ### Bengaluru

# %%
driver = webdriver.Chrome(r"D:\chromedriver.exe")  # Optional argument, if not specified will search path.
driver.get('https://www.cars24.com/');

time.sleep(5)

wait = WebDriverWait(driver, 10)
element = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')))
element.click()

element2 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div[2]/div[2]/button')))
element2.click()

# %%
element3 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[8]/div/div/div/div/div[2]/ul/li[6]/a/span/img')))
element3.click()

element4 = wait.until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div[1]/header/div/div[2]/div[2]/button')))
element4.click()

# %%
SCROLL_PAUSE_TIME = 20

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

container=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_1l4fi']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container.append(p)

# %%
Make_year=[]
Brand=[]
Model=[]
Transmission=[]
Kms=[]
Owner=[]
variant=[]
Price=[]
City=[]

# %%
container1=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//div[@class='_7udZZ']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container1.append(p)
    
for i in range(0,len(container1)):
    Price.append(container1[i])

# %%
container2=[]
Product_Name_tag=driver.find_elements(By.XPATH,"//ul[@class='bVR0c']")
for k in Product_Name_tag:
    p=k.text.split("\n")
    container2.append(p)

# %%
for i in range(0,len(container2)):
    if 'Hybrid' in container[i][1]:
        variant.append('Petrol + Ev')
    elif 'HYBRID' in container[i][1]:
        variant.append('Petrol + Ev')
    else:
        variant.append(container2[i][2])
    
for i in range(0,len(container)):
    a=container[i][0]
    Make_year.append(a[0:4])
    Brand.append(a[5::])
    Model.append(container[i][1])
    Kms.append(container[i][2])
    Owner.append(container[i][3])
    City.append("Bengaluru")
    if 'Automatic' in container[i][1]:
        Transmission.append('Automatic')
    elif 'AUTOMATIC' in container[i][1]:
        Transmission.append('Automatic')
    else:
        Transmission.append('Manual')
        
data=list(zip(Make_year,Brand,Model,Transmission,Kms,Owner,variant,City,Price))
              
df8= pd.DataFrame(data, columns=['Make_Year','Brand','Model','Transmission','Kms','Owner','Variant','City','Price'])

df8
# Out:
#     Make_Year               Brand                           Model  \
# 0        2020       Maruti Ertiga         ZXI SMART HYBRID Manual
# 1        2010  Maruti Swift Dzire                      VXI Manual
# 2        2012         Hyundai i10             ERA 1.1 IRDE Manual
# 3        2010         Hyundai i10             ERA 1.1 IRDE Manual
# 4        2010      Hyundai Accent            EXECUTIVE GLE Manual
# ..        ...                 ...                             ...
# 469      2012          Honda Brio          1.2 V MT I VTEC Manual
# 470      2020        Maruti Swift                     ZXI+ Manual
# 471      2020    Mahindra XUV 3OO      W8 (O) DIESEL AT Automatic
# 472      2011         Hyundai i10  SPORTZ 1.2 AT KAPPA2 Automatic
# 473      2018          Tata TIGOR      Revotron XZA 1.2 Automatic
#
#     Transmission        Kms      Owner      Variant       City         Price
# 0         Manual  17,115 km  1st Owner  Petrol + Ev  Bengaluru  [₹11,75,599]
# ...

# %%
driver.quit()

# %% [markdown]
# ### Concat the scrapped data

# %%
frames = [df1, df2,df3,df4,df5,df6,df7,df8]
 
cars_data = pd.concat(frames)
cars_data
# Out:
#     Make_Year                 Brand                           Model  \
# 0        2011  Toyota Corolla Altis                    1.8 G Manual
# 1        2013           Maruti Ritz                      ZXI Manual
# 2        2016         Maruti Baleno            DELTA 1.2 K12 Manual
# 3        2012          Honda Accord                   2.4 MT Manual
# 4        2016       Volkswagen Polo    TRENDLINE 1.2L PETROL Manual
# ..        ...                   ...                             ...
# 469      2012            Honda Brio          1.2 V MT I VTEC Manual
# 470      2020          Maruti Swift                     ZXI+ Manual
# 471      2020      Mahindra XUV 3OO      W8 (O) DIESEL AT Automatic
# 472      2011           Hyundai i10  SPORTZ 1.2 AT KAPPA2 Automatic
# 473      2018            Tata TIGOR      Revotron XZA 1.2 Automatic
#
#     Transmission          Kms      Owner       Variant       City  \
# 0         Manual  1,22,364 km  2nd Owner  Petrol + CNG     Mumbai
# ...

# %%
cars_data.to_csv('Used_cars.csv')
